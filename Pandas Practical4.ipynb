# %%
import pandas as pd

# %% [markdown]
# how to write csv file

# %%
df=pd.read_csv('C:\\Users\\Khushi verma\\Downloads\\235945_856283_bundle_archive\\chennai_reservoir_levels.csv')
print(df)
# Out:
#             Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# 0     01-01-2004     3.9         0.0     268.0              0.0
# 1     02-01-2004     3.9         0.0     268.0              0.0
# 2     03-01-2004     3.9         0.0     267.0              0.0
# 3     04-01-2004     3.9         0.0     267.0              0.0
# 4     05-01-2004     3.8         0.0     267.0              0.0
# 5     06-01-2004     3.8         0.0     266.0              0.0
# 6     07-01-2004     3.8         0.0     266.0              0.0
# 7     08-01-2004     3.7         0.0     265.0              0.0
# 8     09-01-2004     3.7         0.0     264.0              0.0
# 9     10-01-2004     3.7         0.0     264.0              0.0
# 10    11-01-2004     3.6         0.0     263.0              0.0
# 11    12-01-2004     3.6         0.0     262.0              0.0
# 12    13-01-2004     3.6         0.0     261.0              0.0
# 13    14-01-2004     3.5         0.0     260.0              0.0
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Date', 'POONDI', 'CHOLAVARAM', 'REDHILLS', 'CHEMBARAMBAKKAM'], dtype='object')

# %%
df=pd.read_csv('C:\\Users\\Khushi verma\\Downloads\\235945_856283_bundle_archive\\chennai_reservoir_levels.csv',nrows=1)
df
# Out:
#          Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# 0  01-01-2004     3.9         0.0     268.0              0.0

# %%
df=pd.read_csv('C:\\Users\\Khushi verma\\Downloads\\235945_856283_bundle_archive\\chennai_reservoir_levels.csv',nrows=5)
df
# Out:
#          Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# 0  01-01-2004     3.9         0.0     268.0              0.0
# 1  02-01-2004     3.9         0.0     268.0              0.0
# 2  03-01-2004     3.9         0.0     267.0              0.0
# 3  04-01-2004     3.9         0.0     267.0              0.0
# 4  05-01-2004     3.8         0.0     267.0              0.0

# %%
df=pd.read_csv('C:\\Users\\Khushi verma\\Downloads\\235945_856283_bundle_archive\\chennai_reservoir_levels.csv',usecols=[0])
df
# Out:
#             Date
# 0     01-01-2004
# 1     02-01-2004
# 2     03-01-2004
# 3     04-01-2004
# 4     05-01-2004
# 5     06-01-2004
# 6     07-01-2004
# 7     08-01-2004
# 8     09-01-2004
# 9     10-01-2004
# 10    11-01-2004
# 11    12-01-2004
# 12    13-01-2004
# 13    14-01-2004
# 14    15-01-2004
# 15    16-01-2004
# 16    17-01-2004
# 17    18-01-2004
# 18    19-01-2004
# 19    20-01-2004
# 20    21-01-2004
# 21    22-01-2004
# 22    23-01-2004
# 23    24-01-2004
# 24    25-01-2004
# 25    26-01-2004
# 26    27-01-2004
# 27    28-01-2004
# 28    29-01-2004
# 29    30-01-2004
# ...          ...
# 5806  24-11-2019
# 5807  25-11-2019
# 5808  26-11-2019
# 5809  27-11-2019
# 5810  28-11-2019
# 5811  29-11-2019
# 5812  30-11-2019
# 5813  01-12-2019
# 5814  02-12-2019
# 5815  03-12-2019
# 5816  04-12-2019
# 5817  05-12-2019
# 5818  06-12-2019
# 5819  07-12-2019
# 5820  08-12-2019
# 5821  09-12-2019
# 5822  10-12-2019
# 5823  11-12-2019
# 5824  12-12-2019
# 5825  13-12-2019
# ...

# %%
df=pd.read_csv('C:\\Users\\Khushi verma\\Downloads\\235945_856283_bundle_archive\\chennai_reservoir_levels.csv',usecols=[0,1])
df
# Out:
#             Date  POONDI
# 0     01-01-2004     3.9
# 1     02-01-2004     3.9
# 2     03-01-2004     3.9
# 3     04-01-2004     3.9
# 4     05-01-2004     3.8
# 5     06-01-2004     3.8
# 6     07-01-2004     3.8
# 7     08-01-2004     3.7
# 8     09-01-2004     3.7
# 9     10-01-2004     3.7
# 10    11-01-2004     3.6
# 11    12-01-2004     3.6
# 12    13-01-2004     3.6
# 13    14-01-2004     3.5
# 14    15-01-2004     3.5
# 15    16-01-2004     3.4
# 16    17-01-2004     3.4
# 17    18-01-2004     3.4
# 18    19-01-2004     3.4
# 19    20-01-2004     3.4
# 20    21-01-2004     3.3
# 21    22-01-2004     3.3
# 22    23-01-2004     3.3
# 23    24-01-2004     3.3
# 24    25-01-2004     3.2
# 25    26-01-2004     3.2
# 26    27-01-2004     3.9
# 27    28-01-2004     4.9
# 28    29-01-2004     4.9
# 29    30-01-2004     4.9
# ...          ...     ...
# 5806  24-11-2019  1056.0
# 5807  25-11-2019  1011.0
# 5808  26-11-2019   989.0
# 5809  27-11-2019   967.0
# 5810  28-11-2019   945.0
# ...

# %%
df=pd.read_csv('C:\\Users\\Khushi verma\\Downloads\\235945_856283_bundle_archive\\chennai_reservoir_levels.csv',nrows=5)
df
# Out:
#          Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# 0  01-01-2004     3.9         0.0     268.0              0.0
# 1  02-01-2004     3.9         0.0     268.0              0.0
# 2  03-01-2004     3.9         0.0     267.0              0.0
# 3  04-01-2004     3.9         0.0     267.0              0.0
# 4  05-01-2004     3.8         0.0     267.0              0.0
